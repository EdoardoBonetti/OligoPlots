# %% [markdown]
# # A wonderful analysis of an experiment
#
# some description to be added
#
# ## The code developement
#
# ### 1. Importing the libraries
#
# ```python
# from Lab import *
#
# ```
#
# ### 2. Importing the data
#
# ```python
# ex = Experiment()
# ```
#
# ### 3. Data analysis
#
# ```python
# ex.data.head()
# ```
#
# ### 4. Data visualization
#
# ```python
# ex.data.plot()
# ```
#
# ## Conclusion
#
# some conclusion to be added

# %%
from Lab import SingleExperiment, Experiments

# read all the files in the subfolder calld "DSC"
location = "DSC"
id_list = []
for file in os.listdir(location):
    if file.endswith(".txt"):
        id_list.append(file.split(".")[0])


exp1 = SingleExperiment(id_exp1, location)
exp2 = SingleExperiment(id_exp2, location)

# %%
name_experiment = "John"
list_experiments = [exp1, exp2]


experiments = Experiments(name_experiment, list_experiments)

experiments.display
# Out:
# added
# added
#        231116_RBX_RSO_2perc_A_1st_heating_raw_data.txt  \
# 20.64                                        -2.557975
# 20.65                                        -2.567505
# 20.66                                        -2.561700
# 20.67                                        -2.550257
# 20.68                                        -2.540156
# ...                                                ...
# 90.72                                              NaN
# 90.73                                              NaN
# 90.74                                              NaN
# 90.75                                              NaN
# 90.76                                              NaN
#
#        231116_RBX_RSO_4perc_A_1st_heating_raw_data.txt
# 20.64                                              NaN
# 20.65                                              NaN
# 20.66                                              NaN
# 20.67                                              NaN
# ...

# %%
experiments.clean_data

experiments.display
# Out:
#        231116_RBX_RSO_2perc_A_1st_heating_raw_data.txt  \
# 20.98                                        -2.628600
# 20.99                                        -2.625550
# 21.00                                        -2.621150
# 21.01                                        -2.615720
# 21.02                                        -2.611850
# ...                                                ...
# 90.42                                        -3.064280
# 90.43                                        -3.064433
# 90.44                                        -3.064760
# 90.45                                        -3.064850
# 90.46                                        -3.065000
#
#        231116_RBX_RSO_4perc_A_1st_heating_raw_data.txt
# 20.98                                        -1.008258
# 20.99                                        -1.005167
# 21.00                                        -0.995700
# 21.01                                        -0.990320
# ...
