# %%
#import mplcyberpunk

from lab import collect_files , Measurment
from os import listdir
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
#CYBERPUNK = True
location = "DSC/lard/"

list_ids = collect_files(location, extension=".txt")
meas1 = Measurment(list_ids[0], location)
meas2 = Measurment(list_ids[1], location)

print(meas1)
print(meas2)





#list_single_experiments = [SingleExperiment(id, location) for id in list_ids]
#experiments = Experiments(list_single_experiments)
#experiments.clean
#experiments.flat_out
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 location = "DSC/lard/"
#      11 list_ids = collect_files(location, extension=".txt")
# ---> 12 meas1 = Measurment(list_ids[0], location)
#      13 meas2 = Measurment(list_ids[1], location)
#      15 print(meas1)
#
# File <string>:6, in __init__(self, id_exp, location)
#
# File c:\Users\User\OneDrive\Desktop\OligoPlots\lab.py:37, in Measurment.__post_init__(self)
#      35 def __post_init__(self):
#      36     self.data = read_data(self.id_exp, self.location)
# ---> 37     self.clean_data
#
# File c:\Users\User\OneDrive\Desktop\OligoPlots\lab.py:44, in Measurment.clean_data(self)
#      42 self.data = self.data.dropna()
#      43 self.data = self.data.reset_index(drop=True)
# ---> 44 self.data.columns = ["Temperature", "Heat Flow", "Heat Capacity"]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 3 elements

# %%
#plt.style.use("cyberpunk")


experiments_H2 = experiments.filter(["heating"])
plt.figure(figsize=(7, 4), dpi=1000)
title = "DSC thermogram pork lard heating"
plot_data(experiments_H2, title=title, label="lard")
plt.legend(loc="upper right")

#mplcyberpunk.add_glow_effects()

# plt.show()
plt.savefig("DSC_thermogram_heating_lard.svg")#, dpi=1000)

# %%
experiments_C2 = experiments.filter(["cooling"])
plt.figure(figsize=(7, 4), dpi=1000)
title = "DSC thermogram pork lard cooling"
plot_data(experiments_C2, title=title, label="lard")
plt.legend(loc="upper right")
# plt.show()
plt.savefig("DSC_thermogram_cooling_lard.svg")#, dpi=1000)
